# %%
# Contents of the module we are creating 
content = """
s = 'Hello ' 

def say_hi(name):
    print(s + name)

class Greet:
    pass
"""

# Write the above text to a file called my_module.py
# within our current working directory. 
with open('./my_module.py', 'w') as fp:
    fp.write(content)

# %%
#Import the module we've just made! 
import my_module

# %%
try:
    # Try to print the variable s
    print(s)
except NameError:
    # We've caught a NameError exception (error!)
    # We inform the programmer (you) that the variable does not exist
    print("Variable 's' does not exist!")
# Out:
# Variable 's' does not exist!

# %%
# Accessing the variable s in my_module
my_module.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function in my_module
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %% [markdown]
# ### Importing modules using an alias

# %%
# Alias for my_module
import my_module as md

# %%
# Accessing the variable s using an alias
md.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function using an alias for my_module
md.say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
# Accessing the empty class, Greet
md.Greet
# Out:
# my_module.Greet

# %% [markdown]
# ### Importing modules directly

# %%
from my_module import s, say_hi, Greet

# %%
s
# Out:
# 'Hello '

# %%
say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
Greet
# Out:
# my_module.Greet

# %%
from my_module import *

# %%
say_hi('Joanne')
# Out:
# Hello Joanne

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# ### Built-in modules

# %%
help('modules') # this might take a while
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\ProgramData\anaconda3\Lib\pkgutil.py:93: LangChainPendingDeprecationWarning: langchain.indexes.prompts will be removed in the future.If you're relying on these prompts, please open an issue on GitHub to explain your use case.
#   yield from walk_packages(path, info.name+'.', onerror)
# C:\ProgramData\anaconda3\Lib\pkgutil.py:93: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   yield from walk_packages(path, info.name+'.', onerror)
# C:\ProgramData\anaconda3\Lib\pkgutil.py:93: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   yield from walk_packages(path, info.name+'.', onerror)
# C:\ProgramData\anaconda3\Lib\pkgutil.py:78: FutureWarning: The 'optree.integration' module is deprecated and will be removed in version 0.18.0. Please use 'optree.integrations' instead.
#   __import__(info.name)
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\Kerry\AppData\Roaming\Python\Python312\site-packages\tensorboard\_vendor\bleach\_vendor\html5lib\filters\sanitizer.py:29: DeprecationWarning: html5lib's sanitizer is deprecated; see https://github.com/html5lib/html5lib-python/issues/443 and please let us know if Bleach is unsuitable for your needs
#   warnings.warn(_deprecation_msg, DeprecationWarning)
# ---------------------------------------------------------------------------
# Skipped                                   Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 help('modules')
#
# File <frozen _sitebuiltins>:103, in __call__(self, *args, **kwds)
#
# File C:\ProgramData\anaconda3\Lib\pydoc.py:2096, in Helper.__call__(self, request)
#    2094 if request is not self._GoInteractive:
#    2095     try:
# -> 2096         self.help(request)
#    2097     except ImportError as err:
#    2098         self.output.write(f'{err}\n')
#
# File C:\ProgramData\anaconda3\Lib\pydoc.py:2145, in Helper.help(self, request, is_cli)
#    2143 elif request == 'symbols': self.listsymbols()
#    2144 elif request == 'topics': self.listtopics()
# -> 2145 elif request == 'modules': self.listmodules()
#    2146 elif request[:8] == 'modules ':
#    2147     self.listmodules(request.split()[1])
#
# File C:\ProgramData\anaconda3\Lib\pydoc.py:2303, in Helper.listmodules(self, key)
#    2301             def onerror(modname):
#    2302                 callback(None, modname, None)
# -> 2303             ModuleScanner().run(callback, onerror=onerror)
#    2304             self.list(modules.keys())
#    2305             self.output.write('''
#    2306 Enter any module name to get more help.  Or, type "modules spam" to search
#    2307 for modules whose name or summary contain the string "spam".
#    2308 ''')
#
# File C:\ProgramData\anaconda3\Lib\pydoc.py:2332, in ModuleScanner.run(self, callback, key, completer, onerror)
#    2329             if name.lower().find(key) >= 0:
#    2330                 callback(None, modname, desc)
# -> 2332 for importer, modname, ispkg in pkgutil.walk_packages(onerror=onerror):
#    2333     if self.quit:
#    2334         break
#
# File C:\ProgramData\anaconda3\Lib\pkgutil.py:93, in walk_packages(path, prefix, onerror)
#      90 # don't traverse path items we've seen before
#      91 path = [p for p in path if not seen(p)]
# ---> 93 yield from walk_packages(path, info.name+'.', onerror)
#
# File C:\ProgramData\anaconda3\Lib\pkgutil.py:78, in walk_packages(path, prefix, onerror)
#      76 if info.ispkg:
#      77     try:
# ---> 78         __import__(info.name)
#      79     except ImportError:
#      80         if onerror is not None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\testing\__init__.py:53
#      42 from .._typing import PathLike
#      43 from .data import (
#      44     get_california_housing,
#      45     get_cancer,
#    (...)
#      50     make_sparse_regression,
#      51 )
# ---> 53 hypothesis = pytest.importorskip("hypothesis")
#      55 # pylint:disable=wrong-import-position,wrong-import-order
#      56 from hypothesis import strategies
#
# File C:\ProgramData\anaconda3\Lib\site-packages\_pytest\outcomes.py:296, in importorskip(modname, minversion, reason)
#     294         if reason is None:
#     295             reason = f"could not import {modname!r}: {exc}"
# --> 296         raise Skipped(reason, allow_module_level=True) from None
#     297 mod = sys.modules[modname]
#     298 if minversion is None:
#
# Skipped: could not import 'hypothesis': No module named 'hypothesis'

# %%
# Import math module 
import math

# Use the sqrt function in the math module
x = math.sqrt(81)
print('The square root of 81 is equal to {}'.format(x))

# List all functions in math module 
list_all= dir(math)
print('Functions in the math module: {}'.format(list_all))
# Out:
# The square root of 81 is equal to 9.0
# Functions in the math module: ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']
